# %%
import pandas as pd
import matplotlib as mp

# %%
import numpy as np

# %%
df = pd.read_csv('zomato_dataset.csv')
df.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6216\246286664.py in ?()
#       1 df = pd.read_csv('zomato_dataset.csv')
# ----> 2 df.show()
#
# ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
df.head()
# Out:
#   Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0      Doner King            3.9              4.2            39
# 1      Doner King            3.9              4.2            39
# 2      Doner King            3.9              4.2            39
# 3      Doner King            3.9              4.2            39
# 4      Doner King            3.9              4.2            39
#
#    Delivery Votes   Cuisine  Place Name        City                 Item Name  \
# 0               0  Fast Food   Malakpet   Hyderabad       Platter Kebab Combo
# 1               0  Fast Food   Malakpet   Hyderabad   Chicken Rumali Shawarma
# 2               0  Fast Food   Malakpet   Hyderabad    Chicken Tandoori Salad
# 3               0  Fast Food   Malakpet   Hyderabad         Chicken BBQ Salad
# 4               0  Fast Food   Malakpet   Hyderabad  Special Doner Wrap Combo
#
#   Best Seller  Votes  Prices
# 0  BESTSELLER     84   249.0
# 1  BESTSELLER     45   129.0
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (123657, 12)

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 2                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123652  Ariena Boutique Hotel            3.9              4.2            13
# 123653  Ariena Boutique Hotel            3.9              4.2            13
# 123654  Ariena Boutique Hotel            3.9              4.2            13
# 123655  Ariena Boutique Hotel            3.9              4.2            13
# 123656  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (20228, 12)

# %%
df['Restaurant Name'].value_counts()
# Out:
# Restaurant Name
# Domino's Pizza               595
# McDonald's                   594
# Pizza Hut                    427
# KFC                          261
# Burger King                  248
#                             ...
# Paradise Biryani               1
# Jai Bhavani Snacks Center      1
# Cafe Central                   1
# Havmor Havfunn Ice Cream       1
# Farzi Cafe                     1
# Name: count, Length: 554, dtype: int64

# %%
df.City.value_counts()
# Out:
# City
# Jaipur          2774
# Hyderabad       2408
# Chennai         2360
# Bangalore       2271
# Ahmedabad       1823
# Kolkata         1614
# Kochi           1457
# Mumbai          1371
# Lucknow         1262
# Pune            1227
# Raipur           848
# New Delhi        601
# Goa              157
# Malleshwaram      23
# Magrath Road      22
# Banaswadi         10
# Name: count, dtype: int64

# %%
city_Labels= df.City.value_counts().index
city_Labels[:10]
# Out:
# Index([' Jaipur', ' Hyderabad', ' Chennai', ' Bangalore', ' Ahmedabad',
#        ' Kolkata', ' Kochi', ' Mumbai', ' Lucknow', ' Pune'],
#       dtype='str', name='City')

# %%
city_values= df.City.value_counts().values 
city_values[:10]
# Out:
# array([2774, 2408, 2360, 2271, 1823, 1614, 1457, 1371, 1262, 1227])

# %%
# Example of adding a slight 'pop' to the first slice
plt.pie(x=city_values[:10], labels=city_Labels[:10], autopct="%1.0f%%", explode=[0.1] + [0]*9)
plt.title("Top 10 Cities by Value")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Example of adding a slight 'pop' to the first slice
# ----> 2 plt.pie(x=city_values[:10], labels=city_Labels[:10], autopct="%1.0f%%", explode=[0.1] + [0]*9)
#       3 plt.title("Top 10 Cities by Value")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# Your existing code
plt.pie(x=city_values[:10], labels=city_Labels[:10], autopct="%1.0f%%", explode=[0.1] + [0]*9)
plt.title("Top 10 Cities by Value")
plt.show()

# %%
df.head()
df.shape
